# %%
import requests
from io import BytesIO 
import pandas as pd 
import seaborn as sns 
from tqdm import tqdm 
import matplotlib.pyplot as plt


# 네이버 금융 일자별 순매수 정보 자동저장 프로그램 
page = 1 
url = "https://finance.naver.com/sise/investorDealTrendDay.nhn?bizdate=20200922&sosok=&page={0}".format(page) 
resp = requests.get(url) 
html = BytesIO(resp.content) 
df = pd.read_html(html)[0] 
 
cols = df.columns 
df = pd.DataFrame(columns = cols) 

# 반복문을 통해서 전체 데이터 불러와서 df와 합치기 
for page in tqdm(range(1, 200)): # tqdm은 반복문의 progress bar를 보기 위한 라이브러리 
    url = "https://finance.naver.com/sise/investorDealTrendDay.nhn?bizdate=20200922&sosok=&page={0}".format(page) 
    resp = requests.get(url) 
    html = BytesIO(resp.content) 
    df_single = pd.read_html(html)[0] 
    df = pd.concat([df, df_single]) 
df = df.dropna() 
df = df.reset_index(drop=True) # 일정하지 않은 인덱스 번호를 재 정의 
print(df)
# Out:
# 100%|██████████| 199/199 [00:38<00:00,  5.21it/s]
#             날짜      개인     외국인     기관계      기관                               \
#             날짜      개인     외국인     기관계    금융투자     보험  투신(사모)     은행 기타금융기관
# 0     20.09.22  9913.0  -143.0 -7691.0 -4898.0  -30.0  -927.0  -68.0  -49.0
# 1     20.09.21   410.0  -783.0   392.0  1138.0    7.0  -473.0  -26.0   19.0
# 2     20.09.18 -1405.0  1473.0  -158.0   763.0 -151.0  -643.0  -38.0    3.0
# 3     20.09.17  4587.0 -1244.0 -3358.0 -2139.0  -77.0  -711.0   16.0   -5.0
# 4     20.09.16  1432.0  1792.0 -3051.0 -1118.0 -184.0 -1370.0  -21.0   11.0
# ...        ...     ...     ...     ...     ...    ...     ...    ...    ...
# 1985  12.08.28  1452.0 -1146.0  -291.0   246.0  263.0 -1191.0   57.0  -60.0
# 1986  12.08.27 -1942.0  3506.0 -1241.0  1330.0  258.0 -3227.0 -123.0  -52.0
# 1987  12.08.24   717.0 -2162.0  1448.0   588.0  192.0  -595.0   23.0   -6.0
# 1988  12.08.23  -371.0  1016.0  -505.0   860.0 -938.0  -841.0   80.0  -24.0
# 1989  12.08.22  -260.0  1863.0 -1479.0   217.0 -234.0 -1701.0  -30.0  -43.0
#
#                 기타법인
#         연기금등    기타법인
# 0    -1720.0 -2079.0
# 1     -273.0   -19.0
# 2      -91.0    90.0
# 3     -442.0    15.0
# 4     -369.0  -174.0
# ...      ...     ...
# 1985   393.0   -16.0
# 1986   573.0  -323.0
# 1987  1245.0    -3.0
# 1988   358.0  -141.0
# 1989   311.0  -125.0
#
# [1990 rows x 11 columns]

# %%
sns.regplot(x='개인', y='외국인', data=df) 
plt.show() 
sns.regplot(x='개인', y='기관계', data=df) 
plt.show() 
sns.regplot(x='외국인', y='기관계', data=df) 
plt.show()
# Out:
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 3개 연달아 그리기 
fig, axes = plt.subplots(ncols=3) 
fig.set_size_inches(15, 5) 

import itertools as it 

for ax, comb in zip(axes, it.combinations(['개인','외국인','기관계'], 2)): 
    sns.regplot(x=comb[0], y=comb[1], data=df, ax=ax) 
fig.tight_layout() 

plt.show()
# Out:
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/yunhyejin/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)
